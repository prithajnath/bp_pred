# %%
import pandas as pd
import numpy as np
import os

# %%
files = {
    "train": "VitalDB_Train_Subset_Subset.parquet",
    "aami_cal": "VitalDB_AAMI_Cal_Subset_Subset.parquet",
    "aami_test": "VitalDB_AAMI_Test_Subset_Subset.parquet",
    "calbased_test": "VitalDB_CalBased_Test_Subset_Subset.parquet",
    "calfree_test": "VitalDB_CalFree_Test_Subset_Subset.parquet",
}

# %%
train_df = pd.read_parquet(os.path.join("data",  "pulsedb-balanced-training-and-testing", files["train"]))
train_df
# Out:
#          Age   BMI         DBP Gender  Height         SBP      Subject  Weight
# 0       48.0  20.7   87.991244    [M]   177.4  130.705807  [p000001_1]    65.0
# 1       48.0  20.7   89.147989    [M]   177.4  129.738382  [p000001_1]    65.0
# 2       48.0  20.7   83.794773    [M]   177.4  131.321428  [p000001_1]    65.0
# 3       48.0  20.7  104.949780    [M]   177.4  157.716530  [p000001_1]    65.0
# 4       48.0  20.7   76.922314    [M]   177.4  123.773013  [p000001_1]    65.0
# ...      ...   ...         ...    ...     ...         ...          ...     ...
# 465475  79.0  22.1   48.521635    [M]   169.6  102.922644  [p006090_1]    63.5
# 465476  79.0  22.1   47.101663    [M]   169.6   93.396314  [p006090_1]    63.5
# 465477  79.0  22.1   51.315156    [M]   169.6  108.512630  [p006090_1]    63.5
# 465478  79.0  22.1   51.234743    [M]   169.6  111.088148  [p006090_1]    63.5
# 465479  79.0  22.1   49.628671    [M]   169.6  105.177344  [p006090_1]    63.5
#
# ...
